# %%
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from gym_wordle import GymWordle
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
env = DummyVecEnv([lambda: GymWordle()])
model = DQN('MultiInputPolicy', env, verbose = 1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=1000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1795     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1816     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2060     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1816     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2060     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.088    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2185     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.088    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2185     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 902      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 120      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.91     |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 902      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 120      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.91     |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 778      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 144      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.77     |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 778      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 144      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.77     |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 729      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 168      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.83     |
# |    n_updates        | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 729      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 168      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.83     |
# |    n_updates        | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 707      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 192      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.39     |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 707      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 192      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.39     |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 693      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 216      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.31     |
# |    n_updates        | 28       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 693      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 216      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.31     |
# |    n_updates        | 28       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 683      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 240      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.78     |
# |    n_updates        | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 683      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 240      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.78     |
# |    n_updates        | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 685      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 264      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.16     |
# |    n_updates        | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 685      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 264      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.16     |
# |    n_updates        | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 684      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 288      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.69     |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 684      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 288      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.69     |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 683      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 312      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.89     |
# |    n_updates        | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 683      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 312      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.89     |
# |    n_updates        | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 674      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 336      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.67     |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 674      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 336      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.67     |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 659      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 360      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.8      |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 659      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 360      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.8      |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 655      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 384      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87     |
# |    n_updates        | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 655      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 384      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87     |
# |    n_updates        | 70       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 649      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 408      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 649      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 408      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 647      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 432      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.45     |
# |    n_updates        | 82       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 647      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 432      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.45     |
# |    n_updates        | 82       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 641      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 456      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.81     |
# |    n_updates        | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 641      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 456      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.81     |
# |    n_updates        | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 640      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 480      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.94     |
# |    n_updates        | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 640      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 480      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.94     |
# |    n_updates        | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 639      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 504      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.44     |
# |    n_updates        | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 639      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 504      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.44     |
# |    n_updates        | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 640      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 528      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.58     |
# |    n_updates        | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 640      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 528      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.58     |
# |    n_updates        | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 641      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 552      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.35     |
# |    n_updates        | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 641      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 552      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.35     |
# |    n_updates        | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 642      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 576      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.4      |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 642      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 576      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.4      |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 647      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 600      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.88     |
# |    n_updates        | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 647      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 600      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.88     |
# |    n_updates        | 124      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 650      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 624      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.29     |
# |    n_updates        | 130      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 650      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 624      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.29     |
# |    n_updates        | 130      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 646      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 648      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.2      |
# |    n_updates        | 136      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 646      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 648      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.2      |
# |    n_updates        | 136      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 641      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 672      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47     |
# |    n_updates        | 142      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 641      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 672      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47     |
# |    n_updates        | 142      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 640      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 696      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08     |
# |    n_updates        | 148      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 640      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 696      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08     |
# |    n_updates        | 148      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 642      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 720      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.46     |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 642      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 720      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.46     |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 641      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 744      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 160      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 641      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 744      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 160      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 640      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 768      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.35     |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 640      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 768      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.35     |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 638      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 792      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.12     |
# |    n_updates        | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 638      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 792      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.12     |
# |    n_updates        | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 816      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 178      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 816      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 178      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 840      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54     |
# |    n_updates        | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 840      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54     |
# |    n_updates        | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 633      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 864      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.94     |
# |    n_updates        | 190      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 633      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 864      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.94     |
# |    n_updates        | 190      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 634      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 888      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 634      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 888      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 196      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 636      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 912      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 202      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 636      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 912      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 202      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 936      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.29     |
# |    n_updates        | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 936      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.29     |
# |    n_updates        | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 960      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 214      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 637      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 960      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 214      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 636      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 981      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.36     |
# |    n_updates        | 220      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 636      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 981      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.36     |
# |    n_updates        | 220      |
# ----------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
env.close()
# Out:
# C:\Users\konkanok\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# C:\Users\konkanok\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:259: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
model.save("model/dqn_wordle")
# Out:
# C:\Users\konkanok\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path 'model' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
model = DQN.load("model/dqn_wordle", env=env)

# %%
env.reset()
env.render()
# Out:
# C:\Users\konkanok\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:259: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = env.step(action)
    env.render()
    if dones[0]:
        break
# Out:
# C:\Users\konkanok\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:259: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
